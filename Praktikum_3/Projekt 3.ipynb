# %%
p1 = line([(10,10),(10,12)])
p2 = line([(10,12),(12,12)])
p3 = line([(12,12),(12,10)])
p4 = line([(10,10),(12,10)])
p1 + p2 + p3 + p4
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
data = []
x = 10
y = 18
data = [(x,x), (x,y), (y,y),(y,x), (x,x)]
for a in range (1, 3):
    data.append((x,x+(y-x)/4*a))
    x = x+(y-x)/4*a
    data.append((x-6,x))
    data.append((x-6,x+4))
    data.append((x-2,x+4))
   
    
    
line(data)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
data = []
x = 10
y = 18
length = y-x
data = [(x,x), (x,y), (y,y),(y,x),(x,x), (x,x+length/4)]

line(data)

for a in range (1,2):
    
    x = x+length/4
    x1 = x-(3*length/4)
    y = (y-length/4)
    y1 = (y-(3*length/4))
    data.append((x1,x))
    data.append((x1,y))
    data.append((x-length/4,y))

    length = length/2
    data.append((x,x+length/4))
    

line(data)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
data = []
x = 10


return range
# Out:
#   File "<ipython-input-115-5f79066ebf04>", line 6
#     return range
# SyntaxError: 'return' outside function

# %%
data = []
x = 10
y = 18
length = y-x
data = [(x,x), (x,y), (y,y),(y,x),(x,x)]

def appendLeft(x,y,length):
    data.append((x,y-3*length/4))
    data.append((x-length/2,y-3*length/4))
    data.append((x-length/2,y-length/4))
    data.append((x,y-length/4))
    data.append((x,y))

def appendAbove(x,y,length):
    data.append((x+length/4,y))
    data.append((x+length/4,y+length/2))
    data.append((x+3*length/4,y+length/2))
    data.append((x+3*length/4,y))
    data.append((x+length,y))

def appendRight(x,y,length):
    data.append((x+length,y-length/4))
    data.append((x+3*length/2,y-length/4))
    data.append((x+3*length/2,y-3*length/4))
    data.append((x+length,y-3*length/4))
    data.append((x+length,y-length))
    
def appendBelow(x,y,length):
    data.append((x+3*length/4,y-length))
    data.append((x+3*length/4,y-3*length/2))
    data.append((x+length/4,y-3*length/2))
    data.append((x+length/4,y-length))
    data.append((x,y-length))
    
def appendToLeft(x,y,length):
    appendBelow(x,y,length)
    appendLeft(x,y,length)
    appendAbove(x,y,length)
    data.append((x+length,y+length/2))
    data.append((x+3*length/2,y+length/2))
    #data.append((x+3*length/2,y+3*length/4))

def appendToAbove(x,y,length):
    appendLeft(x,y,length)
    appendAbove(x,y,length)
    appendRight(x,y,length)
    data.append((x+3*length/2,y-length))
    data.append((x+3*length/2,y-3*length/2))

def appendToRight(x,y,length):
    appendAbove(x,y,length)
    appendRight(x,y,length)
    appendBelow(x,y,length)
    data.append((x,y-3*length/2))
    data.append((x-length/2,y-3*length/2))

def appendToBelow(x,y,length):
    appendRight(x,y,length)
    appendBelow(x,y,length)
    appendLeft(x,y,length)
    data.append((x-length/2,y))
    data.append((x-length/2,y+length/2))
    
    
appendLeft(x,y,length)
appendAbove(x,y,length)
appendRight(x,y,length)
appendBelow(x,y,length)
data.append((x,y-3*length/4))  
    
for a in range (1,2):
    x = x-length/2
    y = y-length/4
    length = length/2
    appendToLeft(x,y,length)
    x = x+3*length/2
    y = y+3*length/2
    appendToAbove(x,y,length)
    x = x+3*length/2
    y = y-3*length/2
    appendToRight(x,y,length)
    x = x-3*length/2
    y = y-3*length/2
    appendToBelow(x,y,length)
   
    
line(data)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
data = []
x = 10
y = 18
length = y-x
data = [(x,x), (x,y), (y,y),(y,x),(x,x)]

def appendLeft(x,y,length):
    data.append((x,y-3*length/4))
    data.append((x-length/2,y-3*length/4))
    data.append((x-length/2,y-length/4))
    data.append((x,y-length/4))
    data.append((x,y))

def appendAbove(x,y,length):
    data.append((x+length/4,y))
    data.append((x+length/4,y+length/2))
    data.append((x+3*length/4,y+length/2))
    data.append((x+3*length/4,y))
    data.append((x+length,y))

def appendRight(x,y,length):
    data.append((x+length,y-length/4))
    data.append((x+3*length/2,y-length/4))
    data.append((x+3*length/2,y-3*length/4))
    data.append((x+length,y-3*length/4))
    data.append((x+length,y-length))
    
def appendBelow(x,y,length):
    data.append((x+3*length/4,y-length))
    data.append((x+3*length/4,y-3*length/2))
    data.append((x+length/4,y-3*length/2))
    data.append((x+length/4,y-length))
    data.append((x,y-length))
    
def appendToLeft(x,y,length):
    appendBelow(x,y,length)
    appendLeft(x,y,length)
    appendAbove(x,y,length)
    data.append((x+length,y+length/2))
    data.append((x+3*length/2,y+length/2))
    #data.append((x+3*length/2,y+3*length/4))

def appendToAbove(x,y,length):
    x = x+3*length/2
    y = y+3*length/2
    appendLeft(x,y,length)
    appendAbove(x,y,length)
    appendRight(x,y,length)
    data.append((x+3*length/2,y-length))
    data.append((x+3*length/2,y-3*length/2))

def appendToRight(x,y,length):
    x = x+3*length
    y = y
    appendAbove(x,y,length)
    appendRight(x,y,length)
    appendBelow(x,y,length)
    data.append((x,y-3*length/2))
    data.append((x-length/2,y-3*length/2))

def appendToBelow(x,y,length):
    x = x+3*length/2
    y = y-3*length/2
    appendRight(x,y,length)
    appendBelow(x,y,length)
    appendLeft(x,y,length)
    data.append((x-length/2,y))
    data.append((x-length/2,y+length/2))
    
    
appendLeft(x,y,length)
appendAbove(x,y,length)
appendRight(x,y,length)
appendBelow(x,y,length)
data.append((x,y-3*length/4))
x = x-length/2
y = y-length/4
length = length/2
    
for a in range (1,2):
    appendToLeft(x,y,length)
    appendToAbove(x,y,length)
    appendToRight(x,y,length)
    appendToBelow(x,y,length)
    x = x-length/2
    y = y-length/4
    length = length/2
    appendToBelow(x,y,length)
   
    
line(data)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
data = []
eingabe = 6
x = 20
y = x
length = eingabe * 4

for a in range (0,eingabe/2+eingabe%2):
    data.append((x,y))
    length = -length/4
    y = y-length
    data.append((x,y))
    x = x+length
    data.append((x,y))

    
line(data)
# Out:
# Graphics object consisting of 1 graphics primitive
